# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 city_weather = requests.get(city_url).json()
#       2 city_weather
#
# NameError: name 'city_url' is not defined

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" +weather_api_key + "&q=" +city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anamur
# Processing Record 2 of Set 1 | vila velha
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | stanley
# Processing Record 7 of Set 1 | lillehammer
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | papatowai
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | forster
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | alesund
# Processing Record 14 of Set 1 | freetown
# Processing Record 15 of Set 1 | isafjordur
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | edinburgh of the seven seas
# Processing Record 18 of Set 1 | olonkinbyen
# Processing Record 19 of Set 1 | dudinka
# Processing Record 20 of Set 1 | molina
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | mandalgovi
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | bilibino
# Processing Record 26 of Set 1 | butembo
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | huntsville
# Processing Record 29 of Set 1 | badger
# Processing Record 30 of Set 1 | udachny
# Processing Record 31 of Set 1 | ta`u
# Processing Record 32 of Set 1 | sillamae
# Processing Record 33 of Set 1 | amnat charoen
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | lihue
# Processing Record 36 of Set 1 | mafinga
# Processing Record 37 of Set 1 | afaahiti
# Processing Record 38 of Set 1 | kaohsiung
# Processing Record 39 of Set 1 | vilyuchinsk
# Processing Record 40 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 1 | hastings
# Processing Record 42 of Set 1 | tura
# Processing Record 43 of Set 1 | airuk
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | grytviken
# Processing Record 46 of Set 1 | necochea
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | breves
# Processing Record 49 of Set 1 | canton
# Processing Record 50 of Set 1 | tazacorte
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | afua
# Processing Record 2 of Set 2 | bonthe
# Processing Record 3 of Set 2 | ban karon
# Processing Record 4 of Set 2 | sarmiento
# Processing Record 5 of Set 2 | saipan
# Processing Record 6 of Set 2 | rongelap
# Processing Record 7 of Set 2 | thunder bay
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | richards bay
# Processing Record 10 of Set 2 | invercargill
# Processing Record 11 of Set 2 | owen sound
# Processing Record 12 of Set 2 | walvis bay
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | nar'yan-mar
# Processing Record 16 of Set 2 | constantia
# Processing Record 17 of Set 2 | sabha
# Processing Record 18 of Set 2 | gamba
# Processing Record 19 of Set 2 | puerto baquerizo moreno
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | mineiros
# Processing Record 22 of Set 2 | crateus
# Processing Record 23 of Set 2 | klyuchi
# Processing Record 24 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 25 of Set 2 | puerto natales
# Processing Record 26 of Set 2 | harrismith
# Processing Record 27 of Set 2 | belvedere
# Processing Record 28 of Set 2 | antsiranana
# Processing Record 29 of Set 2 | hamilton
# Processing Record 30 of Set 2 | hirara
# Processing Record 31 of Set 2 | pinarbasi
# Processing Record 32 of Set 2 | happy valley-goose bay
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | mzimba
# Processing Record 35 of Set 2 | asau
# Processing Record 36 of Set 2 | yamada
# Processing Record 37 of Set 2 | carthage
# Processing Record 38 of Set 2 | sault ste. marie
# Processing Record 39 of Set 2 | sinop
# Processing Record 40 of Set 2 | sillod
# Processing Record 41 of Set 2 | kenai
# Processing Record 42 of Set 2 | mattoon
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | nieves
# Processing Record 46 of Set 2 | awjilah
# Processing Record 47 of Set 2 | karratha
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | esmeraldas
# Processing Record 0 of Set 3 | puerto ayora
# Processing Record 1 of Set 3 | jumla
# Processing Record 2 of Set 3 | cooma
# Processing Record 3 of Set 3 | labrador city
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | paracuru
# Processing Record 7 of Set 3 | daru
# Processing Record 8 of Set 3 | waterloo
# Processing Record 9 of Set 3 | hawaiian paradise park
# Processing Record 10 of Set 3 | fale old settlement
# Processing Record 11 of Set 3 | balakhta
# Processing Record 12 of Set 3 | ormara
# Processing Record 13 of Set 3 | kishtwar
# Processing Record 14 of Set 3 | laguna
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | tikrit
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | mogocha
# Processing Record 19 of Set 3 | pa daet
# Processing Record 20 of Set 3 | gubkinskiy
# Processing Record 21 of Set 3 | pirane
# Processing Record 22 of Set 3 | marondera
# Processing Record 23 of Set 3 | kilindoni
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | paracale
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | remire-montjoly
# Processing Record 29 of Set 3 | aasiaat
# Processing Record 30 of Set 3 | tazovsky
# Processing Record 31 of Set 3 | vorgashor
# Processing Record 32 of Set 3 | warwick

# %%
print(city_date)
# Out:
# 1698450458

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       iwye  53.9299   25.7727    278.26        94         100        3.77
# 1     saipan  15.1355  145.7010    302.54        84          40        3.60
# 2   holualoa  19.6228 -155.9522    300.25        75          40        5.66
# 3   sidareja  -7.4846  108.7923    300.03        73          46        0.02
# 4  adamstown -25.0660 -130.1015    296.29        77          36        3.09
#
#   Country        Date
# 0      BY  1698450301
# 1      MP  1698450301
# 2      US  1698450301
# 3      ID  1698450302
# 4      PN  1698450302

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iwye  53.9299   25.7727    278.26        94         100
# 1           saipan  15.1355  145.7010    302.54        84          40
# 2         holualoa  19.6228 -155.9522    300.25        75          40
# 3         sidareja  -7.4846  108.7923    300.03        73          46
# 4        adamstown -25.0660 -130.1015    296.29        77          36
#
#          Wind Speed Country        Date
# City_ID
# 0              3.77      BY  1698450301
# 1              3.60      MP  1698450301
# 2              5.66      US  1698450301
# 3              0.02      ID  1698450302
# 4              3.09      PN  1698450302

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Turn date integer into an understandable date for graph title
import datetime
from datetime import datetime

# city_date_string = str(city_date)
# datetime_obj = time.strftime(city_date_string, "%ms").datetuple()
# date = datetime_obj.date()

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],edgecolor="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],edgecolor="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],edgecolor="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],edgecolor="black",facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Spped (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression(x, y):

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
